# %% [markdown]
# <a href="https://colab.research.google.com/github/daqichen/CIFAR10/blob/main/Model_with_Batch_Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regularized Model with Data Augmentation and Batch Normalization
#
# The following model differs from the regularized model with data augmentation by having a batch normalization layer after each convolutional and desne layer. The model performs batch normalization a total of seven times in a single forward pass. The model is trained over 150 epochs using the Adam optimizer. It achieves a prediction accuracy of 88.58% on the validation set.

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline

# %%
def data_loader(test=False):
  # load dataset
  (trainX, trainY), (testX, testY) = cifar10.load_data()
  # normalize x values
  trainX, testX = trainX.astype('float32')/255.0, testX.astype('float32')/255.0
  # one hot encode y values
  trainY, testY = to_categorical(trainY), to_categorical(testY)
  if (test):
    # return train set and test set
    return trainX, trainY, testX, testY
  else:
    # randomly sample 20% of data from train set
    mask_indices = np.random.choice(np.arange(trainX.shape[0]), size=int(trainX.shape[0] * 0.2), replace=False)
    mask_arr = np.zeros(trainX.shape[0])
    mask_arr[mask_indices] = 1
    # create validation set using random sample
    valX, valY = trainX[mask_arr == 1], trainY[mask_arr == 1]
    # remove random sample from train set
    trainX, trainY = trainX[mask_arr == 0], trainY[mask_arr == 0]
    # return train set and validation set
    return trainX, trainY, valX, valY

# %%
def data_generator(trainX, trainY, batch_size=64, width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True):
  # create data iterator
  data_gen = ImageDataGenerator(width_shift_range=width_shift_range, height_shift_range=height_shift_range, horizontal_flip=horizontal_flip)
  data_iter = data_gen.flow(trainX, trainY, batch_size=batch_size)
  # calculate steps per epoch
  steps_per_epoch = int(trainX.shape[0]/batch_size)
  # return data iterator and steps per epoch
  return data_iter, steps_per_epoch

# %%
# define ConvNet model
def model(optimizer=Adam(), loss='categorical_crossentropy'):
  # initialize model
  model = Sequential()
  # add layers to model
  model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(32, 32, 3)))
  model.add(BatchNormalization())
  model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D((2, 2)))
  model.add(Dropout(0.2))
  model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(BatchNormalization())
  model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D((2, 2)))
  model.add(Dropout(0.3))
  model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(BatchNormalization())
  model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
  model.add(BatchNormalization())
  model.add(MaxPooling2D((2, 2)))
  model.add(Dropout(0.4))
  model.add(Flatten())
  model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))
  model.add(Dense(10, activation='softmax'))
  # compile model
  model.compile(optimizer=optimizer, loss=loss, metrics=['accuracy'])
  return model

# %%
# display training metrics and plot learning curves
def training_summary(history, loss, accuracy, test=False):
  # define x-axis of plots
  epochs = np.arange(len(history.history['loss'])) + 1
  # determine if evaluating performance on test set or validation set
  label = 'test' if test else 'validation'
  plt.figure(figsize=(15,30))
  # plot losses
  plt.subplot(621)
  plt.tight_layout()
  plt.title('Cross-Entropy Loss', fontsize=16)
  plt.xlabel('Epoch', fontsize=14)
  plt.ylabel('Loss', fontsize=14)
  plt.plot(epochs, history.history['loss'], color='blue', label='train')
  plt.plot(epochs, history.history['val_loss'], color='orange', label=label)
  plt.legend(loc='upper left')
  # plot accuracies
  plt.subplot(622)
  plt.tight_layout()
  plt.title('Classification Accuracy', fontsize=16)
  plt.xlabel('Epoch', fontsize=14)
  plt.ylabel('Accuracy', fontsize=14)
  plt.plot(epochs, history.history['accuracy'], color='blue', label='train')
  plt.plot(epochs, history.history['val_accuracy'], color='orange', label=label)
  plt.legend(loc='upper left')
  # print final loss and accuracy
  print(f'{label} loss: {loss:.3f} - {label} accuracy: {accuracy:.3f}')

# %%
def predict(model, examples, label_map, transform=lambda x: (255*x).astype('uint8')):
  # make predictions based on example data
  predictions = [label_map[np.argmax(prediction)] for prediction in model.predict(examples)]
  # denormalize image data
  examples = transform(examples)
  for i in range(len(predictions)):
    plt.subplot(6,2,i+3)
    plt.tight_layout()
    # remove axis labels and ticks
    ax = plt.gca().axes
    ax.xaxis.set_ticks([])
    ax.yaxis.set_ticks([])
    # display prediction
    plt.xlabel(predictions[i], fontsize=16)
    # display image
    plt.imshow(examples[i])

# %%
# train the model and evaluate its performance
def train(data_loader, model, optimizer=Adam(), loss='categorical_crossentropy', epochs=100, batch_size=64, test=False, verbose=False):
  # load dataset
  trainX, trainY, valX, valY = data_loader(test=test)
  # define model
  model = model(optimizer=optimizer, loss=loss)
  # fit model
  data_iter, steps_per_epoch = data_generator(trainX, trainY, batch_size=batch_size)
  history = model.fit(data_iter, steps_per_epoch=steps_per_epoch, epochs=epochs, batch_size=batch_size, validation_data=(valX, valY), verbose=verbose)
  # evaluate model
  loss, acc = model.evaluate(valX, valY)
  # summarize training
  training_summary(history, loss, acc, test=test)
  # make predictions
  label_map = {0:'airplane', 1:'automobile', 2:'bird', 3:'cat', 4:'deer', 5:'dog', 6:'frog', 7:'horse', 8:'ship', 9:'truck'}
  predict(model, valX[:10], label_map)

# %%
train(data_loader=data_loader, model=model, epochs=150, verbose=True)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# 170508288/170498071 [==============================] - 6s 0us/step
# Epoch 1/150
# 625/625 [==============================] - 33s 35ms/step - loss: 1.8355 - accuracy: 0.3756 - val_loss: 1.3458 - val_accuracy: 0.5141
# Epoch 2/150
# 625/625 [==============================] - 21s 33ms/step - loss: 1.3188 - accuracy: 0.5279 - val_loss: 1.2207 - val_accuracy: 0.5831
# Epoch 3/150
# 625/625 [==============================] - 23s 36ms/step - loss: 1.1266 - accuracy: 0.6019 - val_loss: 1.0302 - val_accuracy: 0.6396
# Epoch 4/150
# 625/625 [==============================] - 21s 34ms/step - loss: 1.0012 - accuracy: 0.6474 - val_loss: 0.8486 - val_accuracy: 0.6985
# Epoch 5/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.9184 - accuracy: 0.6775 - val_loss: 0.7695 - val_accuracy: 0.7293
# Epoch 6/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.8485 - accuracy: 0.7045 - val_loss: 0.7793 - val_accuracy: 0.7279
# Epoch 7/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.8023 - accuracy: 0.7211 - val_loss: 0.8589 - val_accuracy: 0.7116
# Epoch 8/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.7662 - accuracy: 0.7370 - val_loss: 0.7099 - val_accuracy: 0.7568
# Epoch 9/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.7264 - accuracy: 0.7524 - val_loss: 0.6333 - val_accuracy: 0.7826
# Epoch 10/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.7022 - accuracy: 0.7606 - val_loss: 0.6867 - val_accuracy: 0.7670
# Epoch 11/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.6699 - accuracy: 0.7717 - val_loss: 0.6112 - val_accuracy: 0.7948
# Epoch 12/150
# 625/625 [==============================] - 22s 35ms/step - loss: 0.6447 - accuracy: 0.7811 - val_loss: 0.5946 - val_accuracy: 0.7983
# Epoch 13/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.6314 - accuracy: 0.7837 - val_loss: 0.5665 - val_accuracy: 0.8069
# Epoch 14/150
# 625/625 [==============================] - 22s 34ms/step - loss: 0.6098 - accuracy: 0.7926 - val_loss: 0.5579 - val_accuracy: 0.8056
# Epoch 15/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.5920 - accuracy: 0.7994 - val_loss: 0.5279 - val_accuracy: 0.8187
# Epoch 16/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.5801 - accuracy: 0.8019 - val_loss: 0.5687 - val_accuracy: 0.8078
# Epoch 17/150
# 625/625 [==============================] - 22s 34ms/step - loss: 0.5650 - accuracy: 0.8073 - val_loss: 0.5798 - val_accuracy: 0.8039
# Epoch 18/150
# 625/625 [==============================] - 22s 35ms/step - loss: 0.5509 - accuracy: 0.8111 - val_loss: 0.4663 - val_accuracy: 0.8426
# Epoch 19/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.5411 - accuracy: 0.8177 - val_loss: 0.4686 - val_accuracy: 0.8418
# Epoch 20/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.5359 - accuracy: 0.8187 - val_loss: 0.4888 - val_accuracy: 0.8325
# Epoch 21/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.5242 - accuracy: 0.8223 - val_loss: 0.4403 - val_accuracy: 0.8462
# Epoch 22/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.5155 - accuracy: 0.8252 - val_loss: 0.5014 - val_accuracy: 0.8308
# Epoch 23/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.5022 - accuracy: 0.8288 - val_loss: 0.5033 - val_accuracy: 0.8348
# Epoch 24/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.5022 - accuracy: 0.8302 - val_loss: 0.4880 - val_accuracy: 0.8349
# Epoch 25/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.4920 - accuracy: 0.8332 - val_loss: 0.4528 - val_accuracy: 0.8473
# Epoch 26/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.4804 - accuracy: 0.8363 - val_loss: 0.5957 - val_accuracy: 0.8104
# Epoch 27/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.4799 - accuracy: 0.8374 - val_loss: 0.4365 - val_accuracy: 0.8515
# Epoch 28/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.4733 - accuracy: 0.8382 - val_loss: 0.4353 - val_accuracy: 0.8498
# Epoch 29/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.4645 - accuracy: 0.8436 - val_loss: 0.4961 - val_accuracy: 0.8360
# Epoch 30/150
# 625/625 [==============================] - 20s 32ms/step - loss: 0.4646 - accuracy: 0.8412 - val_loss: 0.4584 - val_accuracy: 0.8457
# Epoch 31/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.4564 - accuracy: 0.8459 - val_loss: 0.4543 - val_accuracy: 0.8455
# Epoch 32/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.4519 - accuracy: 0.8454 - val_loss: 0.4233 - val_accuracy: 0.8584
# Epoch 33/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.4457 - accuracy: 0.8496 - val_loss: 0.4342 - val_accuracy: 0.8501
# Epoch 34/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.4412 - accuracy: 0.8517 - val_loss: 0.3702 - val_accuracy: 0.8707
# Epoch 35/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.4351 - accuracy: 0.8506 - val_loss: 0.3780 - val_accuracy: 0.8712
# Epoch 36/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.4281 - accuracy: 0.8545 - val_loss: 0.3934 - val_accuracy: 0.8656
# Epoch 37/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.4228 - accuracy: 0.8559 - val_loss: 0.3660 - val_accuracy: 0.8737
# Epoch 38/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.4186 - accuracy: 0.8572 - val_loss: 0.4798 - val_accuracy: 0.8391
# Epoch 39/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.4229 - accuracy: 0.8544 - val_loss: 0.3569 - val_accuracy: 0.8764
# Epoch 40/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.4123 - accuracy: 0.8586 - val_loss: 0.5687 - val_accuracy: 0.8177
# Epoch 41/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.4073 - accuracy: 0.8620 - val_loss: 0.4737 - val_accuracy: 0.8407
# Epoch 42/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.4094 - accuracy: 0.8600 - val_loss: 0.4134 - val_accuracy: 0.8581
# Epoch 43/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.4009 - accuracy: 0.8633 - val_loss: 0.4033 - val_accuracy: 0.8666
# Epoch 44/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.4013 - accuracy: 0.8637 - val_loss: 0.3872 - val_accuracy: 0.8667
# Epoch 45/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.3952 - accuracy: 0.8645 - val_loss: 0.3833 - val_accuracy: 0.8695
# Epoch 46/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.3958 - accuracy: 0.8656 - val_loss: 0.3564 - val_accuracy: 0.8800
# Epoch 47/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3929 - accuracy: 0.8659 - val_loss: 0.4261 - val_accuracy: 0.8577
# Epoch 48/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.3852 - accuracy: 0.8682 - val_loss: 0.3536 - val_accuracy: 0.8801
# Epoch 49/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3837 - accuracy: 0.8702 - val_loss: 0.3773 - val_accuracy: 0.8728
# Epoch 50/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3891 - accuracy: 0.8665 - val_loss: 0.3758 - val_accuracy: 0.8735
# Epoch 51/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.3901 - accuracy: 0.8655 - val_loss: 0.4254 - val_accuracy: 0.8618
# Epoch 52/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.3804 - accuracy: 0.8697 - val_loss: 0.3827 - val_accuracy: 0.8726
# Epoch 53/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3807 - accuracy: 0.8694 - val_loss: 0.4102 - val_accuracy: 0.8634
# Epoch 54/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3755 - accuracy: 0.8732 - val_loss: 0.3371 - val_accuracy: 0.8859
# Epoch 55/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3687 - accuracy: 0.8731 - val_loss: 0.3556 - val_accuracy: 0.8787
# Epoch 56/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.3692 - accuracy: 0.8748 - val_loss: 0.3699 - val_accuracy: 0.8781
# Epoch 57/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3672 - accuracy: 0.8752 - val_loss: 0.4013 - val_accuracy: 0.8660
# Epoch 58/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3677 - accuracy: 0.8758 - val_loss: 0.3790 - val_accuracy: 0.8710
# Epoch 59/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3593 - accuracy: 0.8777 - val_loss: 0.3602 - val_accuracy: 0.8769
# Epoch 60/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3623 - accuracy: 0.8763 - val_loss: 0.3581 - val_accuracy: 0.8803
# Epoch 61/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.3568 - accuracy: 0.8781 - val_loss: 0.3609 - val_accuracy: 0.8787
# Epoch 62/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3539 - accuracy: 0.8800 - val_loss: 0.4377 - val_accuracy: 0.8592
# Epoch 63/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3566 - accuracy: 0.8809 - val_loss: 0.4172 - val_accuracy: 0.8660
# Epoch 64/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3497 - accuracy: 0.8820 - val_loss: 0.3512 - val_accuracy: 0.8816
# Epoch 65/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3491 - accuracy: 0.8795 - val_loss: 0.3268 - val_accuracy: 0.8903
# Epoch 66/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3444 - accuracy: 0.8820 - val_loss: 0.3880 - val_accuracy: 0.8687
# Epoch 67/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3385 - accuracy: 0.8826 - val_loss: 0.3782 - val_accuracy: 0.8766
# Epoch 68/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3492 - accuracy: 0.8812 - val_loss: 0.3733 - val_accuracy: 0.8791
# Epoch 69/150
# 625/625 [==============================] - 20s 32ms/step - loss: 0.3472 - accuracy: 0.8804 - val_loss: 0.3637 - val_accuracy: 0.8795
# Epoch 70/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3355 - accuracy: 0.8854 - val_loss: 0.3306 - val_accuracy: 0.8875
# Epoch 71/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3417 - accuracy: 0.8835 - val_loss: 0.3538 - val_accuracy: 0.8814
# Epoch 72/150
# 625/625 [==============================] - 20s 32ms/step - loss: 0.3374 - accuracy: 0.8842 - val_loss: 0.3326 - val_accuracy: 0.8891
# Epoch 73/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3346 - accuracy: 0.8843 - val_loss: 0.3416 - val_accuracy: 0.8868
# Epoch 74/150
# 625/625 [==============================] - 20s 32ms/step - loss: 0.3323 - accuracy: 0.8864 - val_loss: 0.3475 - val_accuracy: 0.8848
# Epoch 75/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3350 - accuracy: 0.8856 - val_loss: 0.3674 - val_accuracy: 0.8778
# Epoch 76/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3268 - accuracy: 0.8877 - val_loss: 0.3784 - val_accuracy: 0.8784
# Epoch 77/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3340 - accuracy: 0.8856 - val_loss: 0.3461 - val_accuracy: 0.8837
# Epoch 78/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3239 - accuracy: 0.8870 - val_loss: 0.3160 - val_accuracy: 0.8962
# Epoch 79/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3311 - accuracy: 0.8875 - val_loss: 0.3390 - val_accuracy: 0.8895
# Epoch 80/150
# 625/625 [==============================] - 20s 32ms/step - loss: 0.3316 - accuracy: 0.8859 - val_loss: 0.3661 - val_accuracy: 0.8800
# Epoch 81/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3228 - accuracy: 0.8906 - val_loss: 0.3296 - val_accuracy: 0.8880
# Epoch 82/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3203 - accuracy: 0.8909 - val_loss: 0.3490 - val_accuracy: 0.8855
# Epoch 83/150
# 625/625 [==============================] - 20s 32ms/step - loss: 0.3210 - accuracy: 0.8921 - val_loss: 0.3542 - val_accuracy: 0.8827
# Epoch 84/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3193 - accuracy: 0.8911 - val_loss: 0.3685 - val_accuracy: 0.8796
# Epoch 85/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.3202 - accuracy: 0.8907 - val_loss: 0.3374 - val_accuracy: 0.8864
# Epoch 86/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.3185 - accuracy: 0.8913 - val_loss: 0.3294 - val_accuracy: 0.8919
# Epoch 87/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3203 - accuracy: 0.8905 - val_loss: 0.3778 - val_accuracy: 0.8769
# Epoch 88/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3114 - accuracy: 0.8944 - val_loss: 0.3461 - val_accuracy: 0.8854
# Epoch 89/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3132 - accuracy: 0.8928 - val_loss: 0.3368 - val_accuracy: 0.8894
# Epoch 90/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.3107 - accuracy: 0.8943 - val_loss: 0.4307 - val_accuracy: 0.8633
# Epoch 91/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3140 - accuracy: 0.8938 - val_loss: 0.3752 - val_accuracy: 0.8798
# Epoch 92/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3100 - accuracy: 0.8931 - val_loss: 0.3642 - val_accuracy: 0.8826
# Epoch 93/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.3128 - accuracy: 0.8927 - val_loss: 0.3513 - val_accuracy: 0.8850
# Epoch 94/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3057 - accuracy: 0.8954 - val_loss: 0.3613 - val_accuracy: 0.8849
# Epoch 95/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3041 - accuracy: 0.8947 - val_loss: 0.3388 - val_accuracy: 0.8896
# Epoch 96/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.3046 - accuracy: 0.8963 - val_loss: 0.3565 - val_accuracy: 0.8810
# Epoch 97/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3028 - accuracy: 0.8945 - val_loss: 0.3479 - val_accuracy: 0.8879
# Epoch 98/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3109 - accuracy: 0.8935 - val_loss: 0.4058 - val_accuracy: 0.8709
# Epoch 99/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3014 - accuracy: 0.8978 - val_loss: 0.3337 - val_accuracy: 0.8905
# Epoch 100/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3033 - accuracy: 0.8966 - val_loss: 0.3924 - val_accuracy: 0.8744
# Epoch 101/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.2940 - accuracy: 0.8992 - val_loss: 0.3437 - val_accuracy: 0.8873
# Epoch 102/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.3040 - accuracy: 0.8964 - val_loss: 0.3683 - val_accuracy: 0.8771
# Epoch 103/150
# 625/625 [==============================] - 20s 32ms/step - loss: 0.2987 - accuracy: 0.8977 - val_loss: 0.3384 - val_accuracy: 0.8887
# Epoch 104/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2955 - accuracy: 0.8991 - val_loss: 0.3966 - val_accuracy: 0.8727
# Epoch 105/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.2970 - accuracy: 0.8975 - val_loss: 0.3334 - val_accuracy: 0.8885
# Epoch 106/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.2929 - accuracy: 0.8998 - val_loss: 0.3440 - val_accuracy: 0.8867
# Epoch 107/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.2939 - accuracy: 0.8992 - val_loss: 0.3131 - val_accuracy: 0.8974
# Epoch 108/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2951 - accuracy: 0.8993 - val_loss: 0.3648 - val_accuracy: 0.8812
# Epoch 109/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2951 - accuracy: 0.8986 - val_loss: 0.3366 - val_accuracy: 0.8896
# Epoch 110/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2923 - accuracy: 0.8984 - val_loss: 0.3777 - val_accuracy: 0.8805
# Epoch 111/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2870 - accuracy: 0.9010 - val_loss: 0.3197 - val_accuracy: 0.8966
# Epoch 112/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.2850 - accuracy: 0.9020 - val_loss: 0.3224 - val_accuracy: 0.8931
# Epoch 113/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2834 - accuracy: 0.9025 - val_loss: 0.3890 - val_accuracy: 0.8763
# Epoch 114/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2931 - accuracy: 0.8994 - val_loss: 0.4580 - val_accuracy: 0.8566
# Epoch 115/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2836 - accuracy: 0.9044 - val_loss: 0.3256 - val_accuracy: 0.8935
# Epoch 116/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2871 - accuracy: 0.8997 - val_loss: 0.3244 - val_accuracy: 0.8944
# Epoch 117/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2864 - accuracy: 0.9012 - val_loss: 0.3324 - val_accuracy: 0.8909
# Epoch 118/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.2794 - accuracy: 0.9032 - val_loss: 0.3535 - val_accuracy: 0.8878
# Epoch 119/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.2877 - accuracy: 0.9024 - val_loss: 0.4129 - val_accuracy: 0.8684
# Epoch 120/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2850 - accuracy: 0.9021 - val_loss: 0.3473 - val_accuracy: 0.8862
# Epoch 121/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2778 - accuracy: 0.9052 - val_loss: 0.3713 - val_accuracy: 0.8791
# Epoch 122/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.2837 - accuracy: 0.9026 - val_loss: 0.3680 - val_accuracy: 0.8811
# Epoch 123/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2839 - accuracy: 0.9034 - val_loss: 0.3104 - val_accuracy: 0.8978
# Epoch 124/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2777 - accuracy: 0.9037 - val_loss: 0.3492 - val_accuracy: 0.8872
# Epoch 125/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2803 - accuracy: 0.9029 - val_loss: 0.3446 - val_accuracy: 0.8892
# Epoch 126/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.2762 - accuracy: 0.9036 - val_loss: 0.3285 - val_accuracy: 0.8884
# Epoch 127/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2785 - accuracy: 0.9030 - val_loss: 0.3787 - val_accuracy: 0.8789
# Epoch 128/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2781 - accuracy: 0.9057 - val_loss: 0.3331 - val_accuracy: 0.8913
# Epoch 129/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2762 - accuracy: 0.9036 - val_loss: 0.3193 - val_accuracy: 0.8944
# Epoch 130/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2691 - accuracy: 0.9074 - val_loss: 0.3196 - val_accuracy: 0.8957
# Epoch 131/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2741 - accuracy: 0.9053 - val_loss: 0.3875 - val_accuracy: 0.8796
# Epoch 132/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2752 - accuracy: 0.9056 - val_loss: 0.3250 - val_accuracy: 0.8963
# Epoch 133/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2728 - accuracy: 0.9049 - val_loss: 0.3314 - val_accuracy: 0.8934
# Epoch 134/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2688 - accuracy: 0.9082 - val_loss: 0.3152 - val_accuracy: 0.8954
# Epoch 135/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2693 - accuracy: 0.9084 - val_loss: 0.3141 - val_accuracy: 0.8935
# Epoch 136/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.2731 - accuracy: 0.9050 - val_loss: 0.3636 - val_accuracy: 0.8822
# Epoch 137/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2745 - accuracy: 0.9070 - val_loss: 0.3555 - val_accuracy: 0.8884
# Epoch 138/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2679 - accuracy: 0.9071 - val_loss: 0.3300 - val_accuracy: 0.8915
# Epoch 139/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2721 - accuracy: 0.9069 - val_loss: 0.3255 - val_accuracy: 0.8951
# Epoch 140/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2703 - accuracy: 0.9078 - val_loss: 0.3352 - val_accuracy: 0.8915
# Epoch 141/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2695 - accuracy: 0.9081 - val_loss: 0.3491 - val_accuracy: 0.8900
# Epoch 142/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.2676 - accuracy: 0.9082 - val_loss: 0.3440 - val_accuracy: 0.8893
# Epoch 143/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2613 - accuracy: 0.9115 - val_loss: 0.3057 - val_accuracy: 0.9014
# Epoch 144/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.2666 - accuracy: 0.9095 - val_loss: 0.3376 - val_accuracy: 0.8916
# Epoch 145/150
# 625/625 [==============================] - 20s 33ms/step - loss: 0.2645 - accuracy: 0.9090 - val_loss: 0.3519 - val_accuracy: 0.8878
# Epoch 146/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2631 - accuracy: 0.9084 - val_loss: 0.3229 - val_accuracy: 0.8941
# Epoch 147/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2655 - accuracy: 0.9086 - val_loss: 0.3335 - val_accuracy: 0.8904
# Epoch 148/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2631 - accuracy: 0.9082 - val_loss: 0.3657 - val_accuracy: 0.8835
# Epoch 149/150
# 625/625 [==============================] - 21s 33ms/step - loss: 0.2639 - accuracy: 0.9092 - val_loss: 0.3480 - val_accuracy: 0.8906
# Epoch 150/150
# 625/625 [==============================] - 21s 34ms/step - loss: 0.2655 - accuracy: 0.9082 - val_loss: 0.3652 - val_accuracy: 0.8858
# 313/313 [==============================] - 1s 3ms/step - loss: 0.3652 - accuracy: 0.8858
# validation loss: 0.365 - validation accuracy: 0.886
